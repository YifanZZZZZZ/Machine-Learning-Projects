# %%
import numpy as np
import matplotlib.pyplot as plt

# This is similar to the code from lecture 1
# to sample from a 2D Gaussian Distribution
mean = [0,2]
cov = [[1, 2], [2, 5]]
# Fix random seed to get consistent results
np.random.seed(1024)
X = np.random.multivariate_normal(mean, cov, 1000)
fig, ax = plt.subplots(figsize=(10, 10))
# c='r', dot color is red
# s=10.0, dot size is 10
# alpha=0.3, dot opacity is 0.3
ax.scatter(X[:,0], X[:,1], c='r', s=10.0, alpha=0.3, label="2D-Gaussian")
ax.grid()
ax.legend(loc = 0)
# Set x/y axis limits
ax.set_xlim([-10, 10])
ax.set_ylim([-10, 10])
fig.show()
# Out:
# <ipython-input-1-b263dc24d3ec>:21: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# TODO: Report the estimate mean and covariance
# of the sampled points
mean = []
mean.append(np.mean(X[:,0]))
mean.append(np.mean(X[:,1]))
print(f"The mean is {mean}.")
print(f"The covariance is {np.cov(X, rowvar=False)}.")
# Out:
# The mean is [0.019092651459051667, 2.0605238541899022].
# The covariance is [[1.03589238 2.06244165]
#  [2.06244165 5.08839176]].

# %%
# TODO: Plot the histogram for the x-coordinates of X
# and y-coordinates of X respectively.
# You can use the plt.hist() function
fig, axs = plt.subplots(2, 1, figsize=(10, 10))

countsX, binsX = np.histogram(X[:,0])
axs[0].hist(binsX[:-1], binsX, weights=countsX)
axs[0].set_title('Histogram of X Dimension')
axs[0].set_xlabel('X Value')
axs[0].set_ylabel('Count')


countsY, binsY = np.histogram(X[:,1])
axs[1].hist(binsY[:-1], binsY, weights=countsY)
axs[1].set_title('Histogram of Y Dimension')
axs[1].set_xlabel('Y Value')
axs[1].set_ylabel('Count')

plt.tight_layout()
plt.show()

# %%
# TODO: Are the x-coordinates of X samples from
# some Gaussian distribution?
# If so, estimate the mean and variance.
# Do the same for the y-coordinates.
import scipy.stats as stats
from scipy.stats import norm
fig, axs = plt.subplots(2, 1, figsize=(10, 10))

# Histogram for x
axs[0].hist(X[:,0], bins=30, density=True, alpha=0.6, color='g')
xmin, xmax = axs[0].get_xlim()
x_values = np.linspace(xmin, xmax, 100)
px = stats.norm.pdf(x_values, np.mean(x), np.std(x))
axs[0].plot(x_values, px, 'k', linewidth=2)
axs[0].set_title('Histogram of X with Gaussian Fit')

axs[1].hist(X[:,1], bins=30, density=True, alpha=0.6, color='b')
ymin, ymax = axs[1].get_ylim()
py = stats.norm.pdf(x_values, np.mean(y), np.std(y))
axs[1].plot(x_values, py, 'k', linewidth=2)
axs[1].set_title('Histogram of Y with Gaussian Fit')

plt.tight_layout()
plt.show()

mean_x, std_x = norm.fit(X[:,0])
mean_y, std_y = norm.fit(X[:,1])
print(f"Both x-coordinates and y-coordinates seem to follow Gaussian distribution.")
print(f"The mean of x-coordinates is {mean_x} and variance is {std_x * std_x}.")
print(f"The mean of y-coordinates is {mean_y} and variance is {std_y * std_y}.")
# TODO: Generate a new 2D scatter plot of 1000 points,
# such that the x-coordinates(y-coordinates) of all the points
# are samples from a 1D Gaussian distribution 
# using the estimated mean and variance based on the x-coordinates(y-coordinates) of X.
# Out:
# Both x-coordinates and y-coordinates seem to follow Gaussian distribution.
# The mean of x-coordinates is 0.019092651459051667 and variance is 1.0348564864741474.
# The mean of y-coordinates is 2.0605238541899022 and variance is 5.083303371449155.

# %%
# Back to the original X
fig, ax = plt.subplots(figsize=(10, 10))
# c='r', dot color is red
# s=10.0, dot size is 10
# alpha=0.3, dot opacity is 0.3
ax.scatter(X[:,0], X[:,1], c='r', s=10.0, alpha=0.3, label="2D-Gaussian")
ax.grid()
ax.legend(loc = 0)
ax.set_xlim([-10, 10])
ax.set_ylim([-10, 10])

# TODO: Plot a line segment with x = [-10, 10]
# and y = 3x + 1 onto the 2D-Gaussian plot.
# The np.linspace() function may be helpful.

fig.show()

# %%
# TODO: Project X onto line y=2x + 2
# and plot the projected points on the 2D space.
# You need to remove this line and assign the projected points to X_proj.
X_proj = np.zeros(X.shape)

# Here we only plot 30 points to check the correctness
fig, ax = plt.subplots(figsize=(10, 10))
ax.scatter(X_proj[:30,0], X_proj[:30,1], c='b', s=10.0, alpha=1.0, label="Projected 2D-Gaussian")
ax.scatter(X[:30,0], X[:30,1], c='r', s=10.0, alpha=1.0, label="2D-Gaussian")
ax.grid()
ax.legend(loc = 0)
ax.set_xlim([-10, 10])
ax.set_ylim([-10, 10])
# You can also add the line from the previous plot for verification.
fig.show()

# %%
# TODO: Draw the histogram of the x-coordinates
# of the projected points.
# Are the x-coordinates of the projected points
# samples from some Gaussian distribution?
# If so, estimate the mean and variance.
